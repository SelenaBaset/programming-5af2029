# %% [markdown]
# # 9. Objects, and putting it together
#
# **Programming (5AF2029)** · Week 12–13 · Université de Neuchâtel · Dr. Selena Baset
#
# [Course home](index.ipynb)  ·  [Previous](08_analysing_data.ipynb)
#
# ---
#
# ## Reading code built from objects, then a full problem from start to finish.
#
# ### Not published yet
#
# This notebook is a placeholder. The material is published in week 12, after the session in which it is introduced.
#
# If you clicked the course link again and this page still looks like this, the topic has not been covered yet. Nothing is missing on your side.
#
# ### What it will cover
#
# - What an object is, and why libraries are built from them
# - Attributes and methods: reading code that uses them
# - Writing one small class of your own
# - A complete case study, from raw data to a stated conclusion
# - The case study doubles as the practice exam
#
# ---
#
# *Programming (5AF2029) · Université de Neuchâtel · Dr. Selena Baset*
