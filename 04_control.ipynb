# %% [markdown]
# # 4. Control
#
# **Programming (5AF2029)** · Week 2–3 · Université de Neuchâtel · Dr. Selena Baset
#
# [Course home](index.ipynb)  ·  [Previous](03_first_steps.ipynb)  ·  [Next](05_data.ipynb)
#
# ---
#
# ## Making a program decide and repeat.
#
# ### Not published yet
#
# This notebook is a placeholder. The material is published in week 2, after the session in which it is introduced.
#
# If you clicked the course link again and this page still looks like this, the topic has not been covered yet. Nothing is missing on your side.
#
# ### What it will cover
#
# - Comparisons and conditions
# - `if`, `elif`, `else`
# - `for` loops over `range`
# - The accumulator pattern
# - `while` loops, and loops that never stop
# - Loops inside loops
# - Running example: a loan repayment schedule, and how many months of cash a company has left
#
# ---
#
# *Programming (5AF2029) · Université de Neuchâtel · Dr. Selena Baset*
