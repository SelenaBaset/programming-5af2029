# %% [markdown]
# # 8. Analysing data
#
# **Programming (5AF2029)** · Week 10–11 · Université de Neuchâtel · Dr. Selena Baset
#
# [Course home](index.ipynb)  ·  [Previous](07_files_and_tables.ipynb)  ·  [Next](09_objects_and_case_study.ipynb)
#
# ---
#
# ## Answering a question with a dataset, and showing the answer.
#
# ### Not published yet
#
# This notebook is a placeholder. The material is published in week 10, after the session in which it is introduced.
#
# If you clicked the course link again and this page still looks like this, the topic has not been covered yet. Nothing is missing on your side.
#
# ### What it will cover
#
# - Selecting rows and columns
# - Filtering and sorting
# - Grouping and summarising
# - Line, bar and histogram charts with matplotlib
# - Labelling a chart so it says what you mean
# - Running example: the company's monthly figures, and a market price series
#
# ---
#
# *Programming (5AF2029) · Université de Neuchâtel · Dr. Selena Baset*
