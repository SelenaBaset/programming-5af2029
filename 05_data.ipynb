# %% [markdown]
# # 5. Data
#
# **Programming (5AF2029)** · Week 4–5 · Université de Neuchâtel · Dr. Selena Baset
#
# [Course home](index.ipynb)  ·  [Previous](04_control.ipynb)  ·  [Next](06_functions_and_faults.ipynb)
#
# ---
#
# ## Holding more than one value at a time.
#
# ### Not published yet
#
# This notebook is a placeholder. The material is published in week 4, after the session in which it is introduced.
#
# If you clicked the course link again and this page still looks like this, the topic has not been covered yet. Nothing is missing on your side.
#
# ### What it will cover
#
# - Lists: building, indexing, slicing
# - Looping over a list
# - Dictionaries: looking things up by name
# - Mutability and aliasing, and the wrong answers they cause
# - Choosing the right container for the job
# - Running example: monthly figures as a list, cost categories as a dictionary
#
# ---
#
# *Programming (5AF2029) · Université de Neuchâtel · Dr. Selena Baset*
