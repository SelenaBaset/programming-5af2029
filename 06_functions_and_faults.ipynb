# %% [markdown]
# # 6. Functions and faults
#
# **Programming (5AF2029)** · Week 6–7 · Université de Neuchâtel · Dr. Selena Baset
#
# [Course home](index.ipynb)  ·  [Previous](05_data.ipynb)  ·  [Next](07_files_and_tables.ipynb)
#
# ---
#
# ## Writing a piece of a program, then checking it is right.
#
# ### Not published yet
#
# This notebook is a placeholder. The material is published in week 6, after the session in which it is introduced.
#
# If you clicked the course link again and this page still looks like this, the topic has not been covered yet. Nothing is missing on your side.
#
# ### What it will cover
#
# - Defining a function, arguments, return values
# - Scope: what a function can and cannot see
# - Why a program built from functions is easier to fix
# - Testing: choosing the inputs that would expose a defect
# - Reading a traceback, and finding faults that produce no error at all
# - Running example: break-even, margin, and a repayment calculator
#
# ---
#
# *Programming (5AF2029) · Université de Neuchâtel · Dr. Selena Baset*
